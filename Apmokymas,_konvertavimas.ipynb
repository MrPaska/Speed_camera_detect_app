# %%
import torch

# %%
# !git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 16094, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 16094 (delta 0), reused 3 (delta 0), pack-reused 16089
# Receiving objects: 100% (16094/16094), 14.81 MiB | 16.27 MiB/s, done.
# Resolving deltas: 100% (11019/11019), done.

# %%
# !python /content/yolov5/train.py --img 640 --batch 8 --epochs 50 --data dataset.yaml --weights "" --cfg yolov5s.yaml --cache
# Out:
# 2023-12-11 18:01:24.888986: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2023-12-11 18:01:24.889039: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2023-12-11 18:01:24.889075: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
#Testing the yolov5s model
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --img 640 --conf 0.25 --source /content/dataset/images/train/86.png
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], source=/content/dataset/images/train/86.png, data=yolov5/data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /content/dataset/images/train/86.png: 544x640 1 momentinis, 1 vidutinis, 1 zona, 42.5ms
# Speed: 0.5ms pre-process, 42.5ms inference, 1.6ms NMS per image at shape (1, 3, 640, 640)
# Results saved to yolov5/runs/detect/exp3

# %%
# !python /content/yolov5/export.py --weights /content/yolov5/runs/train/exp2/weights/best.pt --include tflite --img 640
# Out:
# export: data=yolov5/data/coco128.yaml, weights=['/content/yolov5/runs/train/exp2/weights/best.pt'], imgsz=[640], batch_size=1, device=cpu, half=False, inplace=False, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=17, verbose=False, workspace=4, nms=False, agnostic_nms=False, topk_per_class=100, topk_all=100, iou_thres=0.45, conf_thres=0.25, include=['tflite']
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CPU
#
# Fusing layers...
# YOLOv5s summary: 157 layers, 7018216 parameters, 0 gradients, 15.8 GFLOPs
#
# PyTorch: starting from /content/yolov5/runs/train/exp2/weights/best.pt with output shape (1, 25200, 8) (13.8 MB)
# 2023-12-11 18:17:16.846392: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...

# %%
#Testing the tflite model
# !python /content/yolov5/detect.py --weights /content/yolov5/runs/train/exp2/weights/best-fp16.tflite --img 640 --conf 0.25 --source /content/dataset/images/train/86.png --data dataset.yaml
# Out:
# detect: weights=['/content/yolov5/runs/train/exp2/weights/best-fp16.tflite'], source=/content/dataset/images/train/86.png, data=dataset.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=yolov5/runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-249-gf400bba Python-3.10.12 torch-2.1.0+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# 2023-12-11 18:47:14.328917: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# ...
